# %% [markdown]
# <a href="https://colab.research.google.com/github/Data-Creater-Atlas/Data-Atlas/blob/Seongjong/mission_4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 1. 드라이브 마운트 및 라이브러리 설치
from google.colab import drive
import os, glob, random, re, math, warnings, json, time, io, datetime
from pathlib import Path
import numpy as np
import tifffile as tiff
import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf
from tensorflow.keras import layers, models

# --- 구글 드라이브 연결 ---
drive.mount('/content/drive')

# --- 필요 라이브러리 설치 (오류 원인 제거됨) ---
# !pip -q install -U tifffile imagecodecs

# --- GPU 및 AMP(혼합 정밀도) 설정 ---
print("TF Version:", tf.__version__)
try:
    tf.keras.mixed_precision.set_global_policy('mixed_float16')
    print("AMP Policy:", tf.keras.mixed_precision.global_policy())
except Exception as e:
    print(f"AMP 설정 실패: {e}")

print("\n✅ 환경 설정이 완료되었습니다.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# TF Version: 2.19.0
# AMP Policy: <DTypePolicy "mixed_float16">
#
# ✅ 환경 설정이 완료되었습니다.

# %%
#@title 2. 데이터셋 경로 설정

from pathlib import Path

# --- ⚠️ 본인의 구글 드라이브 경로에 맞게 수정해주세요. ---
ROOT = Path("/content/drive/MyDrive/Data Camp/53.대기오염 배출원 공간 분포 데이터/3.개방데이터/1.데이터")

# --- 미션 4-1 (SN10) 데이터 폴더 경로 ---
TR_IMG_DIR    = ROOT / "Training/01.원천데이터/TS_SN10_SN10"
TR_LABEL_DIR  = ROOT / "Training/02.라벨링데이터/TL_SN10"
VAL_IMG_DIR   = ROOT / "Validation/01.원천데이터/VS_SN10_SN10"
VAL_LABEL_DIR = ROOT / "Validation/02.라벨링데이터/VL_SN10"

print("✅ 데이터 경로가 설정되었습니다.")
print(f"학습 이미지 경로: {TR_IMG_DIR}")
# Out:
# ✅ 데이터 경로가 설정되었습니다.
# 학습 이미지 경로: /content/drive/MyDrive/Data Camp/53.대기오염 배출원 공간 분포 데이터/3.개방데이터/1.데이터/Training/01.원천데이터/TS_SN10_SN10

# %%
#@title 3. 데이터 파일 확인 (이미지 & 라벨 페어링)

def list_pairs(img_dir: Path, lbl_dir: Path):
    imgs = sorted([p for p in Path(img_dir).glob("*.tif")])
    lbls = []
    miss = []
    for p in imgs:
        q = Path(lbl_dir) / (p.stem + ".tif")
        if not q.exists():
            miss.append(p.stem)
        else:
            lbls.append(q)
    if miss:
        print(f"[경고] 라벨 파일 누락 {len(miss)}개: {miss[:3]}")
        imgs = [p for p in imgs if (lbl_dir / f"{p.stem}.tif").exists()]
    return imgs, lbls

tr_imgs, tr_lbls = list_pairs(TR_IMG_DIR, TR_LABEL_DIR)
va_imgs, va_lbls = list_pairs(VAL_IMG_DIR, VAL_LABEL_DIR)
print(f"✅ 파일 페어링 완료: [학습셋] {len(tr_imgs)}쌍, [검증셋] {len(va_imgs)}쌍")
# Out:
# ✅ 파일 페어링 완료: [학습셋] 8000쌍, [검증셋] 1000쌍

# %%
#@title 4. 데이터 로더 및 증강(Augmentation) 함수 정의

CLIP_MAX = 10000.0
IMG_SIZE    = (256, 256)
NUM_CLASSES = 2  # (배경:0, 오염원:1)
BATCH_SIZE  = 8  # ⚠️ TransUNet은 무거우므로 배치 사이즈를 16 또는 8로 줄여야 합니다.
AUTOTUNE    = tf.data.AUTOTUNE
SEED        = 42

# --- TIF 파일 로더 함수 ---
def decode_img_from_bytes_np(b):
    try:
        arr = tiff.imread(io.BytesIO(memoryview(b).tobytes()))
        if arr.ndim == 3 and arr.shape[0] <= 20: arr = np.moveaxis(arr, 0, -1)
        if arr.ndim == 2: arr = np.stack([arr]*3, axis=-1)
        if arr.shape[-1] > 3: arr = arr[..., :3]
        arr = arr.astype(np.float32, copy=False); arr = np.clip(arr, 0, CLIP_MAX) / CLIP_MAX
        return np.nan_to_num(arr, nan=0.0)
    except: return np.zeros((512, 512, 3), dtype=np.float32)

def decode_mask_from_bytes_np(b):
    try:
        m = tiff.imread(io.BytesIO(memoryview(b).tobytes()))
        if m.ndim == 3: m = m[..., 0]
        if not np.issubdtype(m.dtype, np.integer): m = m.astype(np.int64, copy=False)
        m = (m == 10).astype(np.int32, copy=False) # 10 = 오염원(1), 그 외 = 배경(0)
        return m
    except: return np.zeros((512, 512), dtype=np.int32)

def load_pair(img_path, lbl_path):
    img = tf.numpy_function(decode_img_from_bytes_np, [tf.io.read_file(img_path)], tf.float32)
    msk = tf.numpy_function(decode_mask_from_bytes_np, [tf.io.read_file(lbl_path)], tf.int32)
    img.set_shape([None, None, 3]); msk.set_shape([None, None])
    img = tf.image.resize(img, IMG_SIZE, method="bilinear")
    msk = tf.image.resize(msk[..., None], IMG_SIZE, method="nearest")
    return img, tf.cast(msk, tf.float32)

# --- 데이터 증강 함수 ---
def strong_aug(img, m):
    if tf.random.uniform([]) < 0.5: img, m = tf.image.flip_left_right(img), tf.image.flip_left_right(m)
    if tf.random.uniform([]) < 0.5: img, m = tf.image.flip_up_down(img), tf.image.flip_up_down(m)
    k = tf.random.uniform([], 0, 4, dtype=tf.int32); img, m = tf.image.rot90(img, k), tf.image.rot90(m, k)
    if tf.random.uniform([]) < 0.3: img = tf.image.random_brightness(img, 0.08)
    if tf.random.uniform([]) < 0.3: img = tf.image.random_contrast(img, 0.9, 1.1)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, m

print("✅ 데이터 로더 및 증강 함수가 정의되었습니다.")
# Out:
# ✅ 데이터 로더 및 증강 함수가 정의되었습니다.

# %%
#@title 5. TensorFlow 데이터셋 생성
def make_ds(imgs, lbls, train=True, batch_size=BATCH_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(([str(p) for p in imgs], [str(p) for p in lbls]))
    if train:
        ds = ds.shuffle(len(imgs), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(load_pair, num_parallel_calls=AUTOTUNE)
    if train:
        ds = ds.map(strong_aug, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(AUTOTUNE)
    return ds

train_ds = make_ds(tr_imgs, tr_lbls, train=True)
valid_ds = make_ds(va_imgs, va_lbls, train=False)

print("✅ 학습 및 검증 데이터셋이 생성되었습니다.")
# Out:
# ✅ 학습 및 검증 데이터셋이 생성되었습니다.

# %%
#@title 6. Modified TransUNet + Cross-Attention 모델 정의
import tensorflow as tf
from tensorflow.keras import layers, models

# --- 1. 기본 U-Net 블록 (Encoder/Decoder) ---
def conv_block(x, f, drop=0.0):
    x = layers.Conv2D(f, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    x = layers.Conv2D(f, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    if drop > 0: x = layers.SpatialDropout2D(drop)(x)
    return x

# ⚠️ [추가된 부분] 이 함수가 빠져서 오류가 났었습니다.
def enc(x, f, drop=0.0):
    c = conv_block(x, f, drop)
    p = layers.MaxPool2D(2)(c)
    return c, p

def dec(x, skip, f):
    x = layers.Conv2DTranspose(f, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    return conv_block(x, f)

# --- 2. 트랜스포머(Transformer) 관련 블록 ---
class PatchEmbedding(layers.Layer):
    def __init__(self, patch_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size
        self.projection = layers.Conv2D(embed_dim, kernel_size=patch_size, strides=patch_size, padding="VALID")
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))
    def call(self, images):
        patches = self.projection(images); patches = self.flatten(patches); return patches

def transformer_block(x, embed_dim, num_heads, ff_dim, dropout=0.1):
    attn_input = x
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=dropout)(attn_input, attn_input)
    attn_output = layers.Add()([attn_input, attn_output])
    attn_output = layers.LayerNormalization(epsilon=1e-6)(attn_output)

    ffn_input = attn_output
    ffn_output = layers.Dense(ff_dim, activation="relu")(ffn_input)
    ffn_output = layers.Dense(embed_dim)(ffn_output)
    ffn_output = layers.Add()([ffn_input, ffn_output])
    ffn_output = layers.LayerNormalization(epsilon=1e-6)(ffn_output)
    return ffn_output

# --- 3. Cross-Attention 블록 ---
def cross_attention_block(decoder_feature, encoder_feature, embed_dim, num_heads):
    h, w, c = decoder_feature.shape[1:]
    # Decoder Query 준비
    decoder_query = layers.Reshape((h * w, c))(decoder_feature)
    encoder_kv = encoder_feature

    # Cross-Attention 수행
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(
        query=decoder_query, value=encoder_kv, key=encoder_kv
    )

    attn_output = layers.Reshape((h, w, c))(attn_output)
    fused_feature = layers.Add()([decoder_feature, attn_output])
    return layers.LayerNormalization(epsilon=1e-6)(fused_feature)

# --- 4. 모델 조립 ---
def build_transunet_cross_attention(img_size=IMG_SIZE, base=64, C=3,
                                    patch_size_cnn_out=2, embed_dim=768,
                                    num_heads=12, ff_dim=3072, num_transformer_layers=12):
    H, W = img_size
    inp = layers.Input((H, W, C))

    # --- [A] CNN Encoder ---
    s1, p1 = enc(inp,  base,     drop=0.10)
    s2, p2 = enc(p1,   base*2,   drop=0.15)
    s3, p3 = enc(p2,   base*4,   drop=0.20)

    # --- [B] Transformer Encoder ---
    patches = PatchEmbedding(patch_size=patch_size_cnn_out, embed_dim=embed_dim)(p3)

    transformer_features = patches
    for _ in range(num_transformer_layers):
        transformer_features = transformer_block(transformer_features, embed_dim, num_heads, ff_dim)

    bottleneck_dim = img_size[0] // (2**3 * patch_size_cnn_out)
    bottleneck_shape = (bottleneck_dim, bottleneck_dim, embed_dim)
    bott = layers.Reshape(bottleneck_shape)(transformer_features)

    bott_upscaled = layers.Conv2DTranspose(base*4, 2, strides=2, padding="same")(bott)

    # --- [C] Decoder with Cross-Attention ---
    s3_fused = cross_attention_block(s3, transformer_features, embed_dim=embed_dim, num_heads=num_heads)

    d2 = dec(bott_upscaled, s3_fused, base*4)
    d3 = dec(d2, s2, base*2)
    d4 = dec(d3, s1, base)

    out = layers.Conv2D(1, 1, activation="sigmoid", dtype="float32")(d4)

    model = models.Model(inp, out)
    return model

# --- 5. 모델 생성 ---
model = build_transunet_cross_attention()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ re_lu[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 256, 256,  │          0 │ re_lu_1[0][0]     │
# │ (SpatialDropout2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ re_lu_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 128, 128,  │          0 │ re_lu_3[0][0]     │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ re_lu_4[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 64, 64,    │          0 │ re_lu_5[0][0]     │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patch_embedding     │ (None, 256, 768)  │    787,200 │ max_pooling2d_2[… │
# │ (PatchEmbedding)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ patch_embedding[… │
# │ (MultiHeadAttentio… │                   │            │ patch_embedding[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256, 768)  │          0 │ patch_embedding[… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 256, 768)  │      1,536 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256, 768)  │  2,360,064 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256, 768)  │  2,360,064 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256, 768)  │  2,360,064 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256, 768)  │  2,360,064 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 256, 768)  │  2,360,064 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 256, 768)  │  2,360,064 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 256, 768)  │  2,360,064 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 256, 768)  │  2,360,064 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 256, 768)  │  2,360,064 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 256, 768)  │  2,360,064 │ dense_18[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_20[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 256, 768)  │  2,360,064 │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 256, 768)  │ 28,339,968 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_22[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 256, 3072) │  2,362,368 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 256, 768)  │  2,360,064 │ dense_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 256, 768)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_23[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 256, 768)  │      1,536 │ add_23[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 4096, 256) │          0 │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4096, 256) │ 18,902,272 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ reshape_2[0][0],  │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 16, 16,    │          0 │ layer_normalizat… │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 64, 64,    │          0 │ multi_head_atten… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    786,688 │ reshape_1[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 64, 64,    │          0 │ spatial_dropout2… │
# │                     │ 256)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    262,400 │ conv2d_transpose… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64,    │        512 │ add_24[0][0]      │
# │ (LayerNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │    131,200 │ re_lu_7[0][0]     │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 128,  │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │    147,584 │ re_lu_8[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │     32,832 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │     36,928 │ re_lu_10[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │         65 │ re_lu_11[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 421,164,737 (1.57 GB)
#  Trainable params: 421,161,153 (1.57 GB)
#  Non-trainable params: 3,584 (14.00 KB)

# %%
#@title 7. 손실 함수, 평가지표, 옵티마이저 설정
def dice_loss(y_true, y_pred, eps=1e-6):
    y_true, y_pred = tf.cast(y_true, tf.float32), tf.cast(y_pred, tf.float32)
    inter = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denom = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    return 1.0 - (2.0 * inter + eps) / (denom + eps)

def bce_dice_loss(y_true, y_pred):
    bce = tf.reduce_mean(tf.keras.backend.binary_crossentropy(y_true, y_pred), axis=[1, 2])
    return bce + dice_loss(y_true, y_pred)

# 미션 평가지표인 mIoU 설정
class MeanIoU(tf.keras.metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        # 예측값을 0.5 기준으로 0 또는 1로 변환하여 mIoU 계산
        return super().update_state(y_true > 0.5, y_pred > 0.5, sample_weight)

steps_per_epoch = math.ceil(len(tr_imgs) / BATCH_SIZE)
schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate=1e-4, first_decay_steps=steps_per_epoch * 10,
    t_mul=2.0, m_mul=0.8, alpha=1e-6
)
opt = tf.keras.optimizers.AdamW(learning_rate=schedule, weight_decay=1e-4)

# 모델 컴파일
model.compile(optimizer=opt, loss=bce_dice_loss, metrics=[MeanIoU(num_classes=NUM_CLASSES)])
print("✅ 모델 컴파일이 완료되었습니다.")
# Out:
# ✅ 모델 컴파일이 완료되었습니다.

# %%
#@title 8. 콜백 설정 및 모델 학습
# 모델 체크포인트 저장 경로
CKPT_PATH = Path(f"/content/drive/MyDrive/Data Camp/transunet_mission4_best.keras")
CKPT_PATH.parent.mkdir(parents=True, exist_ok=True)

# 학습 진행 상황을 알려주는 콜백
class ProgressLogger(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None): self.epoch_start_time = time.time()
    def on_epoch_end(self, epoch, logs=None):
        elapsed = time.time() - self.epoch_start_time
        print(f"\n[Epoch {epoch+1} 완료] ⏱ {elapsed//60:.0f}분 {elapsed%60:.0f}초", end="")
        if logs: print(f" | loss: {logs.get('loss'):.4f} | val_loss: {logs.get('val_loss'):.4f} | val_mean_io_u: {logs.get('val_mean_io_u'):.4f}")

# 콜백 리스트
cbs = [
    ProgressLogger(),
    tf.keras.callbacks.EarlyStopping(monitor="val_mean_io_u", mode="max", patience=15, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(CKPT_PATH, monitor="val_mean_io_u", mode="max", save_best_only=True, verbose=0)
]

# 모델 학습 실행 (Epochs=120)
history = model.fit(
    train_ds,
    epochs=120,
    validation_data=valid_ds,
    callbacks=cbs
)
print(f"\n✅ 학습 완료! 최적 모델이 {CKPT_PATH}에 저장되었습니다.")
# Out:
# Epoch 1/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 320s 320ms/step - loss: 0.4086 - mean_io_u: 0.8053 - val_loss: 0.5534 - val_mean_io_u: 0.7501
# Epoch 21/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3992 - mean_io_u: 0.8091
# [Epoch 21 완료] ⏱ 1분 51초 | loss: 0.4003 | val_loss: 0.5030 | val_mean_io_u: 0.7675
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3992 - mean_io_u: 0.8091 - val_loss: 0.5030 - val_mean_io_u: 0.7675
# Epoch 22/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3982 - mean_io_u: 0.8103
# [Epoch 22 완료] ⏱ 1분 51초 | loss: 0.3967 | val_loss: 0.4677 | val_mean_io_u: 0.7824
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3982 - mean_io_u: 0.8103 - val_loss: 0.4677 - val_mean_io_u: 0.7824
# Epoch 23/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3922 - mean_io_u: 0.8126
# [Epoch 23 완료] ⏱ 1분 50초 | loss: 0.3940 | val_loss: 0.4520 | val_mean_io_u: 0.7851
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3922 - mean_io_u: 0.8126 - val_loss: 0.4520 - val_mean_io_u: 0.7851
# Epoch 24/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3952 - mean_io_u: 0.8123
# [Epoch 24 완료] ⏱ 1분 50초 | loss: 0.3907 | val_loss: 0.4117 | val_mean_io_u: 0.8039
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3952 - mean_io_u: 0.8123 - val_loss: 0.4117 - val_mean_io_u: 0.8039
# Epoch 25/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3901 - mean_io_u: 0.8138
# [Epoch 25 완료] ⏱ 1분 51초 | loss: 0.3885 | val_loss: 0.4519 | val_mean_io_u: 0.7873
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3901 - mean_io_u: 0.8138 - val_loss: 0.4519 - val_mean_io_u: 0.7873
# Epoch 26/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3867 - mean_io_u: 0.8152
# [Epoch 26 완료] ⏱ 1분 50초 | loss: 0.3865 | val_loss: 0.4379 | val_mean_io_u: 0.7929
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3867 - mean_io_u: 0.8152 - val_loss: 0.4379 - val_mean_io_u: 0.7929
# Epoch 27/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3864 - mean_io_u: 0.8152
# [Epoch 27 완료] ⏱ 1분 50초 | loss: 0.3833 | val_loss: 0.4308 | val_mean_io_u: 0.7950
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3864 - mean_io_u: 0.8152 - val_loss: 0.4308 - val_mean_io_u: 0.7950
# Epoch 28/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3839 - mean_io_u: 0.8160
# [Epoch 28 완료] ⏱ 1분 50초 | loss: 0.3832 | val_loss: 0.4378 | val_mean_io_u: 0.7924
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3839 - mean_io_u: 0.8160 - val_loss: 0.4378 - val_mean_io_u: 0.7924
# Epoch 29/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3869 - mean_io_u: 0.8143
# [Epoch 29 완료] ⏱ 1분 50초 | loss: 0.3823 | val_loss: 0.4334 | val_mean_io_u: 0.7939
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3869 - mean_io_u: 0.8143 - val_loss: 0.4334 - val_mean_io_u: 0.7939
# Epoch 30/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3814 - mean_io_u: 0.8179
# [Epoch 30 완료] ⏱ 1분 50초 | loss: 0.3821 | val_loss: 0.4373 | val_mean_io_u: 0.7927
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3814 - mean_io_u: 0.8179 - val_loss: 0.4373 - val_mean_io_u: 0.7927
# Epoch 31/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3967 - mean_io_u: 0.8113
# [Epoch 31 완료] ⏱ 1분 51초 | loss: 0.3945 | val_loss: 0.5104 | val_mean_io_u: 0.7687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3967 - mean_io_u: 0.8113 - val_loss: 0.5104 - val_mean_io_u: 0.7687
# Epoch 32/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3712 - mean_io_u: 0.8214 - val_loss: 0.4519 - val_mean_io_u: 0.7838
# Epoch 43/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3701 - mean_io_u: 0.8227
# [Epoch 43 완료] ⏱ 1분 51초 | loss: 0.3687 | val_loss: 0.3912 | val_mean_io_u: 0.8120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3701 - mean_io_u: 0.8227 - val_loss: 0.3912 - val_mean_io_u: 0.8120
# Epoch 44/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.3663 - mean_io_u: 0.8244
# [Epoch 44 완료] ⏱ 2분 52초 | loss: 0.3644 | val_loss: 0.3814 | val_mean_io_u: 0.8170
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 172s 172ms/step - loss: 0.3663 - mean_io_u: 0.8244 - val_loss: 0.3814 - val_mean_io_u: 0.8170
# Epoch 45/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.3566 - mean_io_u: 0.8281
# [Epoch 45 완료] ⏱ 1분 49초 | loss: 0.3630 | val_loss: 0.4897 | val_mean_io_u: 0.7691
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 109s 109ms/step - loss: 0.3566 - mean_io_u: 0.8281 - val_loss: 0.4897 - val_mean_io_u: 0.7691
# Epoch 46/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3597 - mean_io_u: 0.8282
# [Epoch 46 완료] ⏱ 1분 50초 | loss: 0.3611 | val_loss: 0.3646 | val_mean_io_u: 0.8245
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 149s 149ms/step - loss: 0.3597 - mean_io_u: 0.8282 - val_loss: 0.3646 - val_mean_io_u: 0.8245
# Epoch 47/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 0.3588 - mean_io_u: 0.8270
# [Epoch 47 완료] ⏱ 5분 25초 | loss: 0.3601 | val_loss: 0.4535 | val_mean_io_u: 0.7857
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 325s 325ms/step - loss: 0.3588 - mean_io_u: 0.8270 - val_loss: 0.4535 - val_mean_io_u: 0.7857
# Epoch 48/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3548 - mean_io_u: 0.8297
# [Epoch 48 완료] ⏱ 1분 51초 | loss: 0.3552 | val_loss: 0.4235 | val_mean_io_u: 0.8009
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 110ms/step - loss: 0.3548 - mean_io_u: 0.8297 - val_loss: 0.4235 - val_mean_io_u: 0.8009
# Epoch 49/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3541 - mean_io_u: 0.8297
# [Epoch 49 완료] ⏱ 1분 50초 | loss: 0.3546 | val_loss: 0.3698 | val_mean_io_u: 0.8222
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3541 - mean_io_u: 0.8297 - val_loss: 0.3698 - val_mean_io_u: 0.8222
# Epoch 50/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3511 - mean_io_u: 0.8303
# [Epoch 50 완료] ⏱ 1분 50초 | loss: 0.3514 | val_loss: 0.4204 | val_mean_io_u: 0.7992
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3511 - mean_io_u: 0.8303 - val_loss: 0.4204 - val_mean_io_u: 0.7992
# Epoch 51/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3511 - mean_io_u: 0.8307
# [Epoch 51 완료] ⏱ 1분 50초 | loss: 0.3519 | val_loss: 0.4171 | val_mean_io_u: 0.7988
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3511 - mean_io_u: 0.8307 - val_loss: 0.4171 - val_mean_io_u: 0.7988
# Epoch 52/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3487 - mean_io_u: 0.8317
# [Epoch 52 완료] ⏱ 1분 50초 | loss: 0.3509 | val_loss: 0.3870 | val_mean_io_u: 0.8143
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 109ms/step - loss: 0.3487 - mean_io_u: 0.8317 - val_loss: 0.3870 - val_mean_io_u: 0.8143
# Epoch 53/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3507 - mean_io_u: 0.8315
# [Epoch 53 완료] ⏱ 1분 50초 | loss: 0.3477 | val_loss: 0.3543 | val_mean_io_u: 0.8297
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 149s 149ms/step - loss: 0.3507 - mean_io_u: 0.8315 - val_loss: 0.3543 - val_mean_io_u: 0.8297
# Epoch 54/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.3483 - mean_io_u: 0.8328
# [Epoch 54 완료] ⏱ 4분 53초 | loss: 0.3465 | val_loss: 0.4035 | val_mean_io_u: 0.8051
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 293s 293ms/step - loss: 0.3483 - mean_io_u: 0.8328 - val_loss: 0.4035 - val_mean_io_u: 0.8051
# Epoch 55/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3473 - mean_io_u: 0.8335
# [Epoch 55 완료] ⏱ 1분 51초 | loss: 0.3462 | val_loss: 0.3965 | val_mean_io_u: 0.8106
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3473 - mean_io_u: 0.8335 - val_loss: 0.3965 - val_mean_io_u: 0.8106
# Epoch 56/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3449 - mean_io_u: 0.8335
# [Epoch 56 완료] ⏱ 1분 51초 | loss: 0.3444 | val_loss: 0.3822 | val_mean_io_u: 0.8172
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3449 - mean_io_u: 0.8335 - val_loss: 0.3822 - val_mean_io_u: 0.8172
# Epoch 57/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3444 - mean_io_u: 0.8342
# [Epoch 57 완료] ⏱ 1분 51초 | loss: 0.3440 | val_loss: 0.3899 | val_mean_io_u: 0.8140
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3444 - mean_io_u: 0.8342 - val_loss: 0.3899 - val_mean_io_u: 0.8140
# Epoch 58/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3413 - mean_io_u: 0.8355
# [Epoch 58 완료] ⏱ 1분 51초 | loss: 0.3409 | val_loss: 0.3612 | val_mean_io_u: 0.8257
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3413 - mean_io_u: 0.8355 - val_loss: 0.3612 - val_mean_io_u: 0.8257
# Epoch 59/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3424 - mean_io_u: 0.8345
# [Epoch 59 완료] ⏱ 1분 51초 | loss: 0.3403 | val_loss: 0.3734 | val_mean_io_u: 0.8193
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 110ms/step - loss: 0.3424 - mean_io_u: 0.8345 - val_loss: 0.3734 - val_mean_io_u: 0.8193
# Epoch 60/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3408 - mean_io_u: 0.8357
# [Epoch 60 완료] ⏱ 1분 50초 | loss: 0.3399 | val_loss: 0.3564 | val_mean_io_u: 0.8286
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 109ms/step - loss: 0.3408 - mean_io_u: 0.8357 - val_loss: 0.3564 - val_mean_io_u: 0.8286
# Epoch 61/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3370 - mean_io_u: 0.8371
# [Epoch 61 완료] ⏱ 1분 50초 | loss: 0.3388 | val_loss: 0.4010 | val_mean_io_u: 0.8073
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3370 - mean_io_u: 0.8371 - val_loss: 0.4010 - val_mean_io_u: 0.8073
# Epoch 62/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3375 - mean_io_u: 0.8374
# [Epoch 62 완료] ⏱ 1분 50초 | loss: 0.3384 | val_loss: 0.3940 | val_mean_io_u: 0.8106
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3375 - mean_io_u: 0.8374 - val_loss: 0.3940 - val_mean_io_u: 0.8106
# Epoch 63/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3387 - mean_io_u: 0.8368
# [Epoch 63 완료] ⏱ 1분 51초 | loss: 0.3377 | val_loss: 0.3941 | val_mean_io_u: 0.8105
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - loss: 0.3387 - mean_io_u: 0.8368 - val_loss: 0.3941 - val_mean_io_u: 0.8105
# Epoch 64/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3365 - mean_io_u: 0.8372
# [Epoch 64 완료] ⏱ 1분 50초 | loss: 0.3369 | val_loss: 0.3676 | val_mean_io_u: 0.8223
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3365 - mean_io_u: 0.8372 - val_loss: 0.3676 - val_mean_io_u: 0.8223
# Epoch 65/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3392 - mean_io_u: 0.8357
# [Epoch 65 완료] ⏱ 1분 50초 | loss: 0.3377 | val_loss: 0.3673 | val_mean_io_u: 0.8227
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3392 - mean_io_u: 0.8357 - val_loss: 0.3673 - val_mean_io_u: 0.8227
# Epoch 66/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3361 - mean_io_u: 0.8384
# [Epoch 66 완료] ⏱ 1분 50초 | loss: 0.3345 | val_loss: 0.3834 | val_mean_io_u: 0.8153
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3361 - mean_io_u: 0.8384 - val_loss: 0.3834 - val_mean_io_u: 0.8153
# Epoch 67/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3365 - mean_io_u: 0.8373
# [Epoch 67 완료] ⏱ 1분 50초 | loss: 0.3358 | val_loss: 0.3796 | val_mean_io_u: 0.8168
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3365 - mean_io_u: 0.8373 - val_loss: 0.3796 - val_mean_io_u: 0.8168
# Epoch 68/120
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.3351 - mean_io_u: 0.8379
# [Epoch 68 완료] ⏱ 1분 50초 | loss: 0.3355 | val_loss: 0.3761 | val_mean_io_u: 0.8186
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 110s 110ms/step - loss: 0.3351 - mean_io_u: 0.8379 - val_loss: 0.3761 - val_mean_io_u: 0.8186
# Epoch 68: early stopping
#
# ✅ 학습 완료! 최적 모델이 /content/drive/MyDrive/Data Camp/transunet_mission4_best.keras에 저장되었습니다.

# %%
#@title 9. 최종 평가 및 샘플 시각화
# --- 1. 가장 성능이 좋았던 가중치로 다시 평가 ---
model.load_weights(CKPT_PATH)
res = model.evaluate(valid_ds, return_dict=True, verbose=1)

print("\n--- 최종 성능 지표 (mIoU) ---")
for k, v in res.items():
    print(f"  - {k:12s}: {float(v):.4f}")
print("--------------------")

# --- 2. 시각화 함수 ---
def overlay_red(img, mask01, alpha=0.35):
    red = np.zeros_like(img, dtype=np.float32); red[..., 0] = 1.0
    m3  = np.repeat(mask01[..., None], 3, axis=-1).astype(np.float32)
    return img*(1 - alpha*m3) + red*(alpha*m3)

def show_samples(ds, n=3):
    for imgs, masks in ds.take(1):
        preds = model.predict(imgs, verbose=0)
        gt = (masks.numpy()[..., 0] > 0.5).astype(np.uint8)
        pr = (preds[..., 0] > 0.5).astype(np.uint8)

        for i in range(min(n, imgs.shape[0])):
            vis = np.clip(imgs[i].numpy(), 0, 1)
            fig, ax = plt.subplots(1, 3, figsize=(14, 4))
            ax[0].imshow(vis); ax[0].set_title("Original Image"); ax[0].axis("off")
            ax[1].imshow(overlay_red(vis, gt[i])); ax[1].set_title("Ground Truth"); ax[1].axis("off")
            ax[2].imshow(overlay_red(vis, pr[i])); ax[2].set_title("Prediction"); ax[2].axis("off")
            plt.tight_layout(); plt.show()

# --- 3. 샘플 시각화 실행 ---
print("\n--- 예측 결과 샘플 ---")
show_samples(valid_ds, n=3)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 0.3524 - mean_io_u: 0.8270
#
# --- 최종 성능 지표 (mIoU) ---
#   - loss        : 0.3543
#   - mean_io_u   : 0.8297
# --------------------
#
# --- 예측 결과 샘플 ---
